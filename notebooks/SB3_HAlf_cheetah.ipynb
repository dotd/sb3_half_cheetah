# %%
# !export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/did1tv/.mujoco/mujoco210/bin

# %%
import gym
import numpy as np

from stable_baselines3 import SAC

env = gym.make("HalfCheetah-v2")

model = SAC("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=1000, log_interval=4)

# model.save("sac_pendulum")

# del model  # remove to demonstrate saving and loading

# model = SAC.load("sac_pendulum")

obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    env.render()
    if done:
        obs = env.reset()
# Out:
# running build_ext
# building 'mujoco_py.cymj' extension
# gcc -pthread -B /home/did1tv/pythons/miniconda_397/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/did1tv/pythons/miniconda_397/include -I/home/did1tv/pythons/miniconda_397/include -fPIC -O2 -isystem /home/did1tv/pythons/miniconda_397/include -fPIC -I/home/did1tv/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py -I/home/did1tv/.mujoco/mujoco210/include -I/home/did1tv/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/numpy/core/include -I/home/did1tv/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/vendor/egl -I/home/did1tv/projects/sb3_half_cheetah/venv/include -I/home/did1tv/pythons/miniconda_397/include/python3.9 -c /home/did1tv/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/cymj.c -o /home/did1tv/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/generated/_pyxbld_2.1.2.14_39_linuxgpuextensionbuilder/temp.linux-x86_64-3.9/home/did1tv/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/cymj.o -fopenmp -w
# gcc -pthread -B /home/did1tv/pythons/miniconda_397/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/did1tv/pythons/miniconda_397/include -I/home/did1tv/pythons/miniconda_397/include -fPIC -O2 -isystem /home/did1tv/pythons/miniconda_397/include -fPIC -I/home/did1tv/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py -I/home/did1tv/.mujoco/mujoco210/include -I/home/did1tv/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/numpy/core/include -I/home/did1tv/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/vendor/egl -I/home/did1tv/projects/sb3_half_cheetah/venv/include -I/home/did1tv/pythons/miniconda_397/include/python3.9 -c /home/did1tv/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/gl/eglshim.c -o /home/did1tv/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/generated/_pyxbld_2.1.2.14_39_linuxgpuextensionbuilder/temp.linux-x86_64-3.9/home/did1tv/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/gl/eglshim.o -fopenmp -w
# /home/did1tv/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/gl/eglshim.c:4:10: fatal error: GL/glew.h: No such file or directory
#     4 | #include <GL/glew.h>
#       |          ^~~~~~~~~~~
# compilation terminated.
# ---------------------------------------------------------------------------
# DistutilsExecError                        Traceback (most recent call last)
# File ~/pythons/miniconda_397/lib/python3.9/distutils/unixccompiler.py:117, in UnixCCompiler._compile(self, obj, src, ext, cc_args, extra_postargs, pp_opts)
#     116 try:
# --> 117     self.spawn(compiler_so + cc_args + [src, '-o', obj] +
#     118                extra_postargs)
#     119 except DistutilsExecError as msg:
#
# File ~/pythons/miniconda_397/lib/python3.9/distutils/ccompiler.py:910, in CCompiler.spawn(self, cmd)
#     909 def spawn(self, cmd):
# --> 910     spawn(cmd, dry_run=self.dry_run)
#
# File ~/pythons/miniconda_397/lib/python3.9/distutils/spawn.py:91, in spawn(cmd, search_path, verbose, dry_run)
#      90     cmd = cmd[0]
# ---> 91 raise DistutilsExecError(
#      92       "command %r failed with exit code %s" % (cmd, exitcode))
#
# DistutilsExecError: command '/usr/bin/gcc' failed with exit code 1
#
# During handling of the above exception, another exception occurred:
#
# CompileError                              Traceback (most recent call last)
# Cell In[2], line 6
#       2 import numpy as np
#       4 from stable_baselines3 import SAC
# ----> 6 env = gym.make("HalfCheetah-v2")
#       8 model = SAC("MlpPolicy", env, verbose=1)
#       9 model.learn(total_timesteps=1000, log_interval=4)
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/gym/envs/registration.py:235, in make(id, **kwargs)
#     234 def make(id, **kwargs):
# --> 235     return registry.make(id, **kwargs)
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/gym/envs/registration.py:129, in EnvRegistry.make(self, path, **kwargs)
#     127     logger.info("Making new env: %s", path)
#     128 spec = self.spec(path)
# --> 129 env = spec.make(**kwargs)
#     130 return env
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/gym/envs/registration.py:89, in EnvSpec.make(self, **kwargs)
#      87     env = self.entry_point(**_kwargs)
#      88 else:
# ---> 89     cls = load(self.entry_point)
#      90     env = cls(**_kwargs)
#      92 # Make the environment aware of which spec it came from.
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/gym/envs/registration.py:27, in load(name)
#      25 def load(name):
#      26     mod_name, attr_name = name.split(":")
# ---> 27     mod = importlib.import_module(mod_name)
#      28     fn = getattr(mod, attr_name)
#      29     return fn
#
# File ~/pythons/miniconda_397/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/gym/envs/mujoco/__init__.py:1
# ----> 1 from gym.envs.mujoco.mujoco_env import MujocoEnv
#       3 # ^^^^^ so that user gets the correct error
#       4 # message if mujoco is not installed correctly
#       5 from gym.envs.mujoco.ant import AntEnv
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/gym/envs/mujoco/mujoco_env.py:12
#       9 import gym
#      11 try:
# ---> 12     import mujoco_py
#      13 except ImportError as e:
#      14     raise error.DependencyNotInstalled(
#      15         "{}. (HINT: you need to install mujoco_py, and also perform the setup instructions here: https://github.com/openai/mujoco-py/.)".format(
#      16             e
#      17         )
#      18     )
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/__init__.py:2
#       1 #!/usr/bin/env python
# ----> 2 from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#       3 from mujoco_py.generated import const
#       4 from mujoco_py.mjrenderpool import MjRenderPool
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/builder.py:504
#     500     return module.lib.__fun
#     503 mujoco_path = discover_mujoco()
# --> 504 cymj = load_cython_ext(mujoco_path)
#     507 # Trick to expose all mj* functions from mujoco in mujoco_py.*
#     508 class dict2(object):
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/builder.py:110, in load_cython_ext(mujoco_path)
#     108             print("Import error. Trying to rebuild mujoco_py.")
#     109     if mod is None:
# --> 110         cext_so_path = builder.build()
#     111         mod = load_dynamic_ext('cymj', cext_so_path)
#     113 return mod
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/builder.py:226, in MujocoExtensionBuilder.build(self)
#     225 def build(self):
# --> 226     built_so_file_path = self._build_impl()
#     227     new_so_file_path = self.get_so_file_path()
#     228     move(built_so_file_path, new_so_file_path)
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/builder.py:296, in LinuxGPUExtensionBuilder._build_impl(self)
#     295 def _build_impl(self):
# --> 296     so_file_path = super()._build_impl()
#     297     fix_shared_library(so_file_path, 'libOpenGL.so', 'libOpenGL.so.0')
#     298     fix_shared_library(so_file_path, 'libEGL.so', 'libEGL.so.1')
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/builder.py:249, in MujocoExtensionBuilder._build_impl(self)
#     247 dist.parse_command_line()
#     248 obj_build_ext = dist.get_command_obj("build_ext")
# --> 249 dist.run_commands()
#     250 built_so_file_path, = obj_build_ext.get_outputs()
#     251 return built_so_file_path
#
# File ~/pythons/miniconda_397/lib/python3.9/distutils/dist.py:966, in Distribution.run_commands(self)
#     961 """Run each command that was seen on the setup script command line.
#     962 Uses the list of commands found and cache of command objects
#     963 created by 'get_command_obj()'.
#     964 """
#     965 for cmd in self.commands:
# --> 966     self.run_command(cmd)
#
# File ~/pythons/miniconda_397/lib/python3.9/distutils/dist.py:985, in Distribution.run_command(self, command)
#     983 cmd_obj = self.get_command_obj(command)
#     984 cmd_obj.ensure_finalized()
# --> 985 cmd_obj.run()
#     986 self.have_run[command] = 1
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/Cython/Distutils/old_build_ext.py:186, in old_build_ext.run(self)
#     182 if self.cython_gdb or [1 for ext in self.extensions
#     183                              if getattr(ext, 'cython_gdb', False)]:
#     184     optimization.disable_optimization()
# --> 186 _build_ext.build_ext.run(self)
#
# File ~/pythons/miniconda_397/lib/python3.9/distutils/command/build_ext.py:340, in build_ext.run(self)
#     337     self.compiler.set_link_objects(self.link_objects)
#     339 # Now actually compile and link everything.
# --> 340 self.build_extensions()
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/mujoco_py/builder.py:149, in custom_build_ext.build_extensions(self)
#     147 except (AttributeError, ValueError):
#     148     pass
# --> 149 build_ext.build_extensions(self)
#
# File ~/projects/sb3_half_cheetah/venv/lib/python3.9/site-packages/Cython/Distutils/old_build_ext.py:195, in old_build_ext.build_extensions(self)
#     193     ext.sources = self.cython_sources(ext.sources, ext)
#     194 # Call original build_extensions
# --> 195 _build_ext.build_ext.build_extensions(self)
#
# File ~/pythons/miniconda_397/lib/python3.9/distutils/command/build_ext.py:449, in build_ext.build_extensions(self)
#     447     self._build_extensions_parallel()
#     448 else:
# --> 449     self._build_extensions_serial()
#
# File ~/pythons/miniconda_397/lib/python3.9/distutils/command/build_ext.py:474, in build_ext._build_extensions_serial(self)
#     472 for ext in self.extensions:
#     473     with self._filter_build_errors(ext):
# --> 474         self.build_extension(ext)
#
# File ~/pythons/miniconda_397/lib/python3.9/distutils/command/build_ext.py:529, in build_ext.build_extension(self, ext)
#     526 for undef in ext.undef_macros:
#     527     macros.append((undef,))
# --> 529 objects = self.compiler.compile(sources,
#     530                                  output_dir=self.build_temp,
#     531                                  macros=macros,
#     532                                  include_dirs=ext.include_dirs,
#     533                                  debug=self.debug,
#     534                                  extra_postargs=extra_args,
#     535                                  depends=ext.depends)
#     537 # XXX outdated variable, kept here in case third-part code
#     538 # needs it.
#     539 self._built_objects = objects[:]
#
# File ~/pythons/miniconda_397/lib/python3.9/distutils/ccompiler.py:574, in CCompiler.compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     572     except KeyError:
#     573         continue
# --> 574     self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#     576 # Return *all* object filenames, not just the ones we just built.
#     577 return objects
#
# File ~/pythons/miniconda_397/lib/python3.9/distutils/unixccompiler.py:120, in UnixCCompiler._compile(self, obj, src, ext, cc_args, extra_postargs, pp_opts)
#     117     self.spawn(compiler_so + cc_args + [src, '-o', obj] +
#     118                extra_postargs)
#     119 except DistutilsExecError as msg:
# --> 120     raise CompileError(msg)
#
# CompileError: command '/usr/bin/gcc' failed with exit code 1
